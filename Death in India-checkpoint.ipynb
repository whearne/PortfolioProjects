# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


df = pd.read_csv(r"C:\Users\Owner\OneDrive\Documents\Data Analyst\Pandas file reading\Deathdata.csv")

df
# Out:
#                         Diseases  Deaths   Male  Female    0-4  5-14  15-29  \
# 0                   Tuberculosis    6845   4624    2221     46    71    612
# 1                       HIV/AIDS     425    299     126      0     3     72
# 2                     Diarrhoeal    9361   4390    4971   1959   392    456
# 3                        Malaria    3621   1796    1825    456   260    442
# 4              Selected tropical     771    398     373     46    50     96
# 5          Respiratory Infection    7155   3791    3364   3895   220    108
# 6              Severe Infections    1598    867     731    870    27     60
# 7                      Parasitic    2984   1594    1390    843   364    432
# 8            Maternal conditions     650      0     650      0     0    482
# 9           Perinatal conditions   10271   5679    4592  10271     0      0
# 10      Nutritional deficiencies    1235    501     734    544    54     74
# 11       Fever of unknown origin    5804   2722    3082    570   174    326
# 12                        Cancer   11201   5987    5214     23    30    570
# 13             Diabetes mellitus    4172   2239    1933      0     7     48
# 14  Neuro-psychiatric conditions    1989   1040     949    182   125    312
# 15       Cardiovascular diseases   42524  26045   16479     46    51    900
# 16          Respiratory Diseases   13984   8043    5941    114    20    108
# 17                     Digestive    8993   6183    2810    410   210    865
# 18                Genito-urinary    4797   3016    1781     46    47    288
# 19          Congenital anomalies    1179    670     509   1012    70     75
# 20              Non communicable    1122    499     623    159   125     60
# 21       Motor Vehicle Accidents    5373   4512     861    114   203   1640
# 22        Unintentional injuries    8625   4981    3644    911   693   1308
# 23                       Suicide    4812   2815    1997      0    78   2160
# 24            Other than suicide     558    441     117     18    20    120
# 25                      Injuries     195    137      58      0    13     72
# 26                         Other   22583  10398   12185    205    85    264
#
#     30-44  45-54  55-69     70  Total
# 0    1382   1270   2224   1240   6845
# 1     234     70     46      0    425
# 2     425    427   1915   3787   9361
# 3     400    313    826    924   3621
# 4     100     87    192    200    771
# 5     116    156    770   1890   7155
# 6      71     70    232    268   1598
# 7     405    265    408    267   2984
# 8     168      0      0      0    650
# 9       0      0      0      0  10271
# 10     73     42    262    186   1235
# 11    338    348   1366   2682   5804
# 12   1620   2162   4315   2481  11201
# 13    176    445   1723   1773   4172
# 14    300    244    444    382   1989
# 15   3428   5792  16050  16257  42524
# 16    336    838   4992   7576  13984
# 17   1890   1618   2440   1560   8993
# 18    582    765   1633   1436   4797
# 19     22      0      0      0   1179
# 20     67     87    232    392   1122
# 21   1498    800    726    392   5373
# 22   1165    696   1502   2350   8625
# 23   1365    544    459    206   4812
# 24    190     70     45     95    558
# 25     50     16     44      0    195
# 26    265    294   2540  18930  22583

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Diseases  27 non-null     object
#  1   Deaths    27 non-null     int64
#  2   Male      27 non-null     int64
#  3   Female    27 non-null     int64
#  4   0-4       27 non-null     int64
#  5   5-14      27 non-null     int64
#  6   15-29     27 non-null     int64
#  7   30-44     27 non-null     int64
#  8   45-54     27 non-null     int64
#  9   55-69     27 non-null     int64
#  10  70        27 non-null     int64
#  11  Total     27 non-null     int64
# dtypes: int64(11), object(1)
# memory usage: 2.7+ KB

# %%
df.shape
# Out:
# (27, 12)

# %%
num = df.select_dtypes(include=np.number).columns
len(num)
# Out:
# 11

# %%
r = 3
c = 4
it = 1
for i in num:
    plt.subplot(r,c,it)
    sns.histplot(df.loc[:,i])
    plt.title(i)
    plt.grid()
    it+=1
plt.tight_layout()
plt.show()

# %%
rate = pd.read_csv(r"C:\Users\Owner\OneDrive\Documents\Data Analyst\Pandas file reading\rate.csv")
rate.head()
# Out:
#    YEAR  POPULATION  RATEBIRTH  RATEDEATH
# 0  1950   376325200     44.175     28.161
# 1  1951   382376948     43.970     27.584
# 2  1952   388799073     43.764     27.008
# 3  1953   395544369     43.558     26.432
# 4  1954   402578596     43.352     25.856

# %%
rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   YEAR        73 non-null     int64
#  1   POPULATION  73 non-null     int64
#  2   RATEBIRTH   73 non-null     float64
#  3   RATEDEATH   73 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 2.4 KB

# %%
rate.shape
# Out:
# (73, 4)

# %%
sns.lineplot(x='YEAR',y='POPULATION',data=rate,color='blue')
plt.grid()
plt.show()

# %%
sns.lineplot(x='YEAR',y='RATEBIRTH',data=rate,color='green')
sns.lineplot(x='YEAR',y='RATEDEATH',data=rate,color='purple')

plt.grid()
plt.show()

# %%
sns.lineplot(x='POPULATION',y='RATEBIRTH',data=rate)
plt.grid()
plt.show()

# %%
sns.lineplot(x='POPULATION',y='RATEDEATH',data=rate)
plt.grid()
plt.show()

# %%
states = pd.read_csv(r"C:\Users\Owner\OneDrive\Documents\Data Analyst\Pandas file reading\states.csv")
states.head()
# Out:
#            States  Male  %Male  Female  %Female  People
# 0  Andhra Pradesh  7868   7.59    5388     6.81   13256
# 1           Assam   942   0.91     922     1.16    1864
# 2           Bihar  5898   5.69    3264     4.12    9162
# 3    Chhattisgarh  1086   1.05     930     1.17    2016
# 4           Delhi  1248   1.20    1534     1.94    2782

# %%
states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   States   35 non-null     object
#  1   Male     35 non-null     int64
#  2   %Male    35 non-null     float64
#  3   Female   35 non-null     int64
#  4   %Female  35 non-null     float64
#  5   People   35 non-null     int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.8+ KB

# %%
states.shape
# Out:
# (35, 6)

# %%
sns.barplot(x='States',y='People',data=states)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='States',y='Female',data=states)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='States',y='Male',data=states)
plt.xticks(rotation=90)
plt.show()
